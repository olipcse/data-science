# %%
import pandas as pd
# %matplotlib inline
tf = pd.read_csv('F:\dataset1_test.csv')
tf1=tf.dropna()

df = pd.DataFrame(tf1)  

df.columns = ["Batsman","Runs","Mins","BF","four","six","SR","Pos","Dismissal","Inns"]

print(df)
batsman1= df[df.Batsman==1]
batsman2=df[df.Batsman==2]
batsman3=df[df.Batsman==3]
batsman4=df[df.Batsman==4]
batsman5=df[df.Batsman==5]
batsman6=df[df.Batsman==6]

print(batsman1)
print(batsman2)
print(batsman3)
print(batsman4)
print(batsman5)
print(batsman6)
# Out:
#      Batsman  Runs   Mins   BF  four  six      SR  Pos Dismissal  Inns
# 0          1    33   78.0   56     5    0   58.92    3    caught     2
# 1          1    33   77.0   49     6    0   67.34    3    caught     4
# 2          1   215  503.0  346    25    1   62.13    3       lbw     1
# 3          1    58   67.0   48     9    0  120.83    3    bowled     3
# 4          1     7   26.0   18     1    0   38.88    3    caught     1
# 5          1     8   40.0   27     1    0   29.62    3    caught     3
# 6          1     6    2.0    3     1    0  200.00    3    caught     1
# 7          1     5   20.0    9     1    0   55.55    3    caught     3
# 8          1   143  387.0  252    17    2   56.74    3    bowled     1
# 9          1    48   98.0   78     8    0   61.53    4    bowled     1
# 10         1     1    8.0    2     0    0   50.00    4    caught     3
# 11         1    27   91.0   68     3    0   39.70    4    caught     1
# ...

# %%
#4th innings stat of individual batsman
batsman1_4= df[(df.Batsman==1)&(df.Inns==4)]
batsman2_4=df[(df.Batsman==2)&(df.Inns==4)]
batsman3_4=df[(df.Batsman==3)&(df.Inns==4)]
batsman4_4=df[(df.Batsman==4)&(df.Inns==4)]
batsman5_4=df[(df.Batsman==5)&(df.Inns==4)]
batsman6_4=df[(df.Batsman==6)&(df.Inns==4)]
print(batsman1_4)
# Out:
#     Batsman  Runs   Mins   BF  four  six      SR  Pos Dismissal  Inns
# 1         1    33   77.0   49     6    0   67.34    3    caught     4
# 14        1    14   35.0   24     2    0   58.33    3       lbw     4
# 20        1    53   78.0   46     4    1  115.21    4   not out     4
# 22        1    55  151.0  125     1    0   44.00    4       lbw     4
# 24        1    30   57.0   58     3    0   51.72    5    caught     4
# 26        1     8   17.0   14     1    0   57.14    3    bowled     4
# 28        1    34  118.0   91     5    0   37.36    4    caught     4
# 32        1    40   84.0   52     5    0   76.92    4    caught     4
# 41        1    28   69.0   48     3    0   58.33    3       lbw     4
# 47        1    37  149.0   99     3    0   37.37    4    caught     4
# 49        1    16   24.0    9     3    0  177.77    3    caught     4

# %%
# total innings played by individual batsman in 4th innings
inns1=batsman1_4.shape[0]
inns2=batsman2_4.shape[0]
inns3=batsman3_4.shape[0]
inns4=batsman4_4.shape[0]
inns5=batsman5_4.shape[0]
inns6=batsman6_4.shape[0]
#notout in 4th innings
notout1=batsman1_4[(batsman1_4.Dismissal=="not out")]
notout2=batsman2_4[(batsman2_4.Dismissal=="not out")]
notout3=batsman3_4[(batsman3_4.Dismissal=="not out")]
notout4=batsman4_4[(batsman4_4.Dismissal=="not out")]
notout5=batsman5_4[(batsman5_4.Dismissal=="not out")]
notout6=batsman6_4[(batsman6_4.Dismissal=="not out")]
finns1=inns1-notout1.shape[0]
finns2=inns2-notout2.shape[0]
finns3=inns3-notout3.shape[0]
finns4=inns4-notout4.shape[0]
finns5=inns5-notout5.shape[0]
finns6=inns6-notout6.shape[0]
runs1=batsman1_4.Runs.sum()
runs2=batsman2_4.Runs.sum()
runs3=batsman3_4.Runs.sum()
runs4=batsman4_4.Runs.sum()
runs5=batsman5_4.Runs.sum()
runs6=batsman6_4.Runs.sum()
#average runs in 4th innings
avg1=runs1/finns1
avg2=runs2/finns2
avg3=runs3/finns3
avg4=runs4/finns4
avg5=runs5/finns5
avg6=runs6/finns6
avg_list=[avg1,avg2,avg3,avg4,avg5,avg6]
avg_list
# Out:
# [34.8, 26.0, 27.0, 47.72727272727273, 84.2, 22.6]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
player = [1, 2, 3, 4, 5, 6]
print("Player VS average run in 4th innings")
_ = plt.plot(player, avg_list, marker = '*', linestyle = 'none')
_ = plt.margins(0.02)
_ = plt.xlabel ('Player')
_ = plt.ylabel ('Average Run')
plt.show()

#ball faced in 4th innings
ballf1=batsman1_4.BF.sum()
ballf2=batsman2_4.BF.sum()
ballf3=batsman3_4.BF.sum()
ballf4=batsman4_4.BF.sum()
ballf5=batsman5_4.BF.sum()
ballf6=batsman6_4.BF.sum()

#average ball faced in 4th innings
avgBF1=ballf1/inns1
avgBF2=ballf2/inns2
avgBF3=ballf3/inns3
avgBF4=ballf4/inns4
avgBF5=ballf5/inns5
avgBF6=ballf6/inns6

avg_bf_list=[avgBF1,avgBF2,avgBF3,avgBF4,avgBF5,avgBF6]
avg_bf_list



import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

print("Player VS average ball faced in 4th innings")
_ = plt.plot(player,avg_bf_list, marker = '*', linestyle = 'none')
_ = plt.margins(0.02)
_ = plt.xlabel ('Player')
_ = plt.ylabel ('Average ball faced')
plt.show()
# Out:
# Player VS average run in 4th innings
# Player VS average ball faced in 4th innings

# %%
#Summation of strike rate for individual batsman
SR1=batsman1.SR.sum()
SR2=batsman2.SR.sum()
SR3=batsman3.SR.sum()
SR4=batsman4.SR.sum()
SR5=batsman5.SR.sum()
SR6=batsman6.SR.sum()

#total boundaries of individual batsman
bn1=(batsman1.four.sum()) + (batsman1.six.sum())
bn2=(batsman2.four.sum()) + (batsman2.six.sum())
bn3=(batsman3.four.sum()) + (batsman3.six.sum())
bn4=(batsman4.four.sum()) + (batsman4.six.sum())
bn5=(batsman5.four.sum()) + (batsman5.six.sum())
bn6=(batsman6.four.sum()) + (batsman6.six.sum())

#Ratio of Strike rate and Boundaries
rat_sn1=SR1/bn1
rat_sn2=SR2/bn2
rat_sn3=SR3/bn3
rat_sn4=SR4/bn4
rat_sn5=SR5/bn5
rat_sn6=SR6/bn6

ratio_list=[rat_sn1,rat_sn2,rat_sn3,rat_sn4,rat_sn5,rat_sn6]
ratio_list
# Out:
# [9.00795918367347,
#  8.540833333333333,
#  9.465139240506328,
#  12.414959349593495,
#  8.564197530864199,
#  11.11127659574468]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
player = [1, 2, 3, 4, 5, 6]
print("Player VS Ratio of Strike Rate and Boundaries")
_ = plt.plot(player, ratio_list, marker = '*', linestyle = 'none')
_ = plt.margins(0.02)
_ = plt.xlabel ('Player')
_ = plt.ylabel ('Ratio')
plt.show()
# Out:
# Player VS Ratio of Strike Rate and Boundaries

# %%
# total innings played by individual batsman 
inns11=batsman1.shape[0]
inns22=batsman2.shape[0]
inns33=batsman3.shape[0]
inns44=batsman4.shape[0]
inns55=batsman5.shape[0]
inns66=batsman6.shape[0]

#notout in total innings
notout11=batsman1[(batsman1.Dismissal=="not out")]
notout22=batsman2[(batsman2.Dismissal=="not out")]
notout33=batsman3[(batsman3.Dismissal=="not out")]
notout44=batsman4[(batsman4.Dismissal=="not out")]
notout55=batsman5[(batsman5.Dismissal=="not out")]
notout66=batsman6[(batsman6.Dismissal=="not out")]
finns11=inns11-notout11.shape[0]
finns22=inns22-notout22.shape[0]
finns33=inns33-notout33.shape[0]
finns44=inns44-notout44.shape[0]
finns55=inns55-notout55.shape[0]
finns66=inns66-notout66.shape[0]

#total individual runs in all innings
runs11=batsman1.Runs.sum()
runs22=batsman2.Runs.sum()
runs33=batsman3.Runs.sum()
runs44=batsman4.Runs.sum()
runs55=batsman5.Runs.sum()
runs66=batsman6.Runs.sum()

#average runs in  innings
avg11=runs11/finns11
avg22=runs22/finns22
avg33=runs33/finns33
avg44=runs44/finns44
avg55=runs55/finns55
avg66=runs66/finns66
tot_avg_list=[avg11,avg22,avg33,avg44,avg55,avg66]
tot_avg_list
# Out:
# [70.81632653061224,
#  62.354166666666664,
#  52.35,
#  51.14035087719298,
#  61.06060606060606,
#  37.77272727272727]

# %%
#TAKING ONLY DISMISSAL COLUMN WHERE BATSMAN WERE LBW'ED
lbw1=batsman1[(batsman1.Dismissal=="lbw")]

lbw2=batsman2[(batsman2.Dismissal=="lbw")]
lbw3=batsman3[(batsman3.Dismissal=="lbw")]
lbw4=batsman4[(batsman4.Dismissal=="lbw")]
lbw5=batsman5[(batsman5.Dismissal=="lbw")]
lbw6=batsman6[(batsman6.Dismissal=="lbw")]


#PROBABILITY OF LBW
rlbw1=lbw1.shape[0]/finns11
rlbw2=lbw2.shape[0]/finns22
rlbw3=lbw3.shape[0]/finns33
rlbw4=lbw4.shape[0]/finns44
rlbw5=lbw5.shape[0]/finns55
rlbw6=lbw6.shape[0]/finns66

lbw_list=[rlbw1,rlbw2,rlbw3,rlbw4,rlbw5,rlbw6]
lbw_list
# Out:
# [0.16326530612244897,
#  0.2916666666666667,
#  0.21666666666666667,
#  0.14035087719298245,
#  0.15151515151515152,
#  0.18181818181818182]

# %%
import seaborn as sns
sns.set()
Batsman=[1,2,3,4,5,6]
_ = sns.swarmplot(x= Batsman, y = lbw_list, data = df)
_ = plt.margins(0.02)
_ = plt.xlabel ('Batsman')
_ = plt.ylabel ('Probability of getting out by lbw')
plt.show()

# %%
#listing only values of Runs Column
new1=batsman1.Runs
new2=batsman2.Runs
new3=batsman3.Runs
new4=batsman4.Runs
new5=batsman5.Runs
new6=batsman6.Runs

#user defined function for calculating variance respect to average runs


def runs_variance(new1, avg11):
    variance = 0
    for i in new1:
        variance += (avg11 - i) ** 2
    return ( variance / len(new1))
    
def runs_variance(new2, avg22):
    variance = 0
    for i in new2:
        variance += (avg22 - i) ** 2
    return ( variance / len(new2))
    
def runs_variance(new3, avg33):
    variance = 0
    for i in new3:
        variance += (avg33 - i) ** 2
    return ( variance / len(new3))
def runs_variance(new4, avg44):
    variance = 0
    for i in new4:
        variance += (avg44 - i) ** 2
    return ( variance / len(new4))
def runs_variance(new4, avg55):
    variance = 0
    for i in new5:
        variance += (avg55 - i) ** 2
    return ( variance / len(new5))
def runs_variance(new6, avg66):
    variance = 0
    for i in new6:
        variance += (avg66 - i) ** 2
    return ( variance / len(new6))


#VARIANCE OF INDIVIDUAL PLAYER

var1=runs_variance(new1, avg11)
var2=runs_variance(new2, avg22)
var3=runs_variance(new3, avg33)
var4=runs_variance(new4, avg44)
var5=runs_variance(new5, avg55)
var6=runs_variance(new6, avg66)
    

    
#LIST OF ALL VARIANCE    
    
var_list=[var1,var2,var3,var4,var5,var6]
var_list
# Out:
# [3287.560767808735,
#  4761.098991720085,
#  2291.7459375000003,
#  2349.6533587909717,
#  2449.996496061089,
#  932.6301652892561]

# %%
import seaborn as sns
sns.set()
player=[1,2,3,4,5,6]
print("Player vs Variance ")
_ = sns.swarmplot(x= player, y = var_list, data = df,dodge=True)
_ = plt.margins(0.02)
_ = plt.xlabel ('Batsman')
_ = plt.ylabel ('Variance')
plt.show()


import seaborn as sns
sns.set()
player=[1,2,3,4,5,6]
print("Player vs Average ")
_ = sns.swarmplot(x= player, y = tot_avg_list, data = df)
_ = plt.margins(0.02)
_ = plt.xlabel ('Batsman')
_ = plt.ylabel ('Average')
plt.show()
# Out:
# Player vs Variance
# Player vs Average

# %%
import seaborn as sns
sns.set()
print("Player vs Minutes Played")
_ = sns.boxplot(x = 'Batsman', y = 'Mins', data = df)
_ = plt.margins(0.02)
_ = plt.xlabel ('Player')
_ = plt.ylabel ('Minutes')
plt.show()
# Out:
# Player vs Minutes Played

# %%
var1=runs_variance(new1, avg11)
var2=runs_variance(new2, avg22)
var3=runs_variance(new3, avg33)
var4=runs_variance(new4, avg44)
var5=runs_variance(new5, avg55)
var6=runs_variance(new6, avg66)

# %%
#prediction of career average of players according to normal distribution
#85% confidence interval is taken
#one tailed test
#in 95% confidence interval alpha level is 0.85
import math

#finding mean,standard deviation, and sample size
mean1=avg11
std1=math.sqrt(var1)
n1=math.sqrt(finns11)

mean2=avg22
std2=math.sqrt(var2)
n2=math.sqrt(finns22)

mean3=avg33
std3=math.sqrt(var3)
n3=math.sqrt(finns33)


mean4=avg44
std4=math.sqrt(var4)
n4=math.sqrt(finns44)

mean5=avg55
std5=math.sqrt(var5)
n5=math.sqrt(finns55)

mean6=avg66
std6=math.sqrt(var6)
n6=math.sqrt(finns66)









#calculating z score
import scipy.stats as st
z=st.norm.ppf(.85)

#functions for calculating confidence interval normal distribution

def z_plus(meanx,stdy,nz):
    return (meanx+(z*(stdy/nz)))

def z_minus(meanx,stdy,nz):
    return (meanx-(z*(stdy/nz)))

print("USING NORMAL DISTRIBUTION\n")

career1p=z_plus(mean1,std1,n1)
career1m=z_minus(mean1,std1,n1)

print("Career Average of Player 1 is between", career1p, "to", career1m)
print("according to normal distribution with 85% confidence interval\n")

career2p=z_plus(mean2,std2,n2)
career2m=z_minus(mean2,std2,n2)

print("Career Average of Player 2 is between", career2p, "to", career2m)
print("according to normal distribution with 85% confidence interval\n")

career3p=z_plus(mean3,std3,n3)
career3m=z_minus(mean3,std3,n3)

print("Career Average of Player 3 is between", career3p, "to", career3m)
print("according to normal distribution with 85% confidence interval\n")

career4p=z_plus(mean4,std4,n4)
career4m=z_minus(mean4,std4,n4)

print("Career Average of Player 4 is between", career4p, "to", career4m)
print("according to normal distribution with 85% confidence interval\n")

career5p=z_plus(mean5,std5,n5)
career5m=z_minus(mean5,std5,n5)

print("Career Average of Player 5 is between", career5p, "to", career5m)
print("according to normal distribution with 85% confidence interval\n")

career6p=z_plus(mean6,std6,n6)
career6m=z_minus(mean6,std6,n6)

print("Career Average of Player 6 is between", career6p, "to", career6m)
print("according to normal distribution with 85% confidence interval")
# Out:
# USING NORMAL DISTRIBUTION
#
# Career Average of Player 1 is between 79.30579012406116 to 62.32686293716333
# according to normal distribution with 85% confidence interval
#
# Career Average of Player 2 is between 72.67641688946777 to 52.031916443865555
# according to normal distribution with 85% confidence interval
#
# Career Average of Player 3 is between 58.75544056141477 to 45.94455943858523
# according to normal distribution with 85% confidence interval
#
# Career Average of Player 4 is between 57.794704341443214 to 44.485997412942744
# according to normal distribution with 85% confidence interval
#
# Career Average of Player 5 is between 69.99092885956728 to 52.13028326164485
# according to normal distribution with 85% confidence interval
#
# Career Average of Player 6 is between 44.52087815453343 to 31.02457639092112
# according to normal distribution with 85% confidence interval

# %%
#prediction of career average of players according to t distribution
#85% confidence interval is taken
#one tailed test
#in 85% confidence interval alpha level is 0.95


#finding t values
from scipy import stats

t1= (stats.t.ppf(0.85, (finns11)-1))
t2= (stats.t.ppf(0.85, (finns22)-1))
t3= (stats.t.ppf(0.85, (finns33)-1))
t4= (stats.t.ppf(0.85, (finns44)-1))
t5= (stats.t.ppf(0.85, (finns55)-1))
t6= (stats.t.ppf(0.85, (finns66)-1))


#confidence interval using t distribution
def t_plus(meanx,stdy,nz,tx):
    return (meanx+(tx*(stdy/nz)))

def t_minus(meanx,stdy,nz,tx):
    return (meanx-(tx*(stdy/nz)))


careertp1=t_plus(mean1,std1,n1,t1)
careertm1=t_minus(mean1,std1,n1,t1)

print("USING t DISTRIBUTION\n")

print("Career Average of Player 1 is between", careertp1, "to", careertm1)
print("according to T distribution with 95% confidence interval\n")

careertp2=t_plus(mean2,std2,n2,t2)
careertm2=t_minus(mean2,std2,n2,t2)

print("Career Average of Player 2 is between", careertp2, "to", careertm2)
print("according to T distribution with 95% confidence interval\n")

careertp3=t_plus(mean3,std3,n3,t3)
careertm3=t_minus(mean3,std3,n3,t3)

print("Career Average of Player 3 is between", careertp3, "to", careertm3)
print("according to T distribution with 95% confidence interval\n")

careertp4=t_plus(mean4,std4,n4,t4)
careertm4=t_minus(mean4,std4,n4,t4)

print("Career Average of Player 4 is between", careertp4, "to", careertm4)
print("according to T distribution with 85% confidence interval\n")

careertp5=t_plus(mean5,std5,n5,t5)
careertm5=t_minus(mean5,std5,n5,t5)

print("Career Average of Player 5 is between", careertp5, "to", careertm5)
print("according to T distribution with 85% confidence interval\n")

careertp6=t_plus(mean6,std6,n6,t6)
careertm6=t_minus(mean6,std6,n6,t6)

print("Career Average of Player 6 is between", careertp6, "to", careertm6)
print("according to T distribution with 85% confidence interval")
# Out:
# USING t DISTRIBUTION
#
# Career Average of Player 1 is between 79.39850463946942 to 62.23414842175507
# according to T distribution with 95% confidence interval
#
# Career Average of Player 2 is between 72.7915726551507 to 51.91676067818263
# according to T distribution with 95% confidence interval
#
# Career Average of Player 3 is between 58.81223759004939 to 45.88776240995061
# according to T distribution with 95% confidence interval
#
# Career Average of Player 4 is between 57.85689887132565 to 44.42380288306031
# according to T distribution with 85% confidence interval
#
# Career Average of Player 5 is between 70.13802003269973 to 51.983192088512396
# according to T distribution with 85% confidence interval
#
# Career Average of Player 6 is between 44.69170099409336 to 30.85375355136119
# according to T distribution with 85% confidence interval

# %%
import numpy as np
#STRIKE RATE AVERAGE OF INDIVIDUAL PLAYER
vsr1=np.mean(batsman1.SR)
vsr2=np.mean(batsman2.SR)
vsr3=np.mean(batsman3.SR)
vsr4=np.mean(batsman4.SR)
vsr5=np.mean(batsman5.SR)
vsr6=np.mean(batsman6.SR)

#STANDARD DEVIATION OF STRIKE RATE
ssr1=np.std(batsman1.SR)
ssr2=np.std(batsman2.SR)
ssr3=np.std(batsman3.SR)
ssr4=np.std(batsman4.SR)
ssr5=np.std(batsman5.SR)
ssr6=np.std(batsman6.SR)

# %%
import scipy.stats as st
z1=st.norm.ppf(.85)

#functions for calculating confidence intervalin normal distribution for strike rate 

def z_splus(meanx,stdy,nz):
    return (meanx+(z1*(stdy/nz)))

def z_sminus(meanx,stdy,nz):
    return (meanx-(z1*(stdy/nz)))

career1ps=z_splus(vsr1,ssr1,n1)
career1ms=z_sminus(vsr1,ssr1,n1)

print("Average SR of Player 1 is between", career1ps, "to", career1ms)
print("according to normal distribution with 85% confidence interval\n")

career2ps=z_splus(vsr2,ssr2,n2)
career2ms=z_sminus(vsr2,ssr2,n2)

print("Average SR of Player 2 is between", career2ps, "to", career2ms)
print("according to normal distribution with 85% confidence interval\n")

career3ps=z_splus(vsr3,ssr3,n3)
career3ms=z_sminus(vsr3,ssr3,n3)

print("Average SR of Player 3 is between", career3ps, "to", career3ms)
print("according to normal distribution with 85% confidence interval\n")

career4ps=z_splus(vsr4,ssr4,n4)
career4ms=z_sminus(vsr4,ssr4,n4)

print("Average SR of Player 4 is between", career4ps, "to", career4ms)
print("according to normal distribution with 85% confidence interval\n")

career5ps=z_splus(vsr5,ssr5,n5)
career5ms=z_sminus(vsr5,ssr5,n5)

print("Average SR of Player 5 is between", career5ps, "to", career5ms)
print("according to normal distribution with 85% confidence interval\n")

career6ps=z_splus(vsr6,ssr6,n6)
career6ms=z_sminus(vsr6,ssr6,n6)

print("Average SR of Player 6 is between", career6ps, "to", career6ms)
print("according to normal distribution with 85% confidence interval\n")
# Out:
# Average SR of Player 1 is between 66.99534683716513 to 56.90360053125594
# according to normal distribution with 85% confidence interval
#
# Average SR of Player 2 is between 56.42846848429704 to 50.003454592626
# according to normal distribution with 85% confidence interval
#
# Average SR of Player 3 is between 61.71418442600048 to 55.12112807399955
# according to normal distribution with 85% confidence interval
#
# Average SR of Player 4 is between 83.28652357580718 to 72.00567981402337
# according to normal distribution with 85% confidence interval
#
# Average SR of Player 5 is between 59.43923667752497 to 50.09234226984348
# according to normal distribution with 85% confidence interval
#
# Average SR of Player 6 is between 52.43630398297478 to 42.514605107934315
# according to normal distribution with 85% confidence interval
